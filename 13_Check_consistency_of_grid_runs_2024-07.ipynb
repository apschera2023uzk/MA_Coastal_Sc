# %%
import xarray as xr
import glob
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D
import sys
import scipy
sys.path.append("/home/qwertz/Dokumente/N_eigene_Dokumente/Geo_Met_MSc/Semester_4_5/Thesis_prep_Juni_23/MA/Notebooks/")
from Sc_module import convert_single_timestamp
from Sc_module import convert_to_float_timestamps
# from Sc_module import ucla_time2useful_time
plt.rc('font', size=12) 

############################################

grid5_00 = "/home/qwertz/UCLA/uclales/Runs/00_GRID_DZ5/" # complete run PC in Santiago
grid_icon_00 ="/home/qwertz/UCLA/uclales/Runs/00_GRID_ICONLES/" # complete run Supercomputer Santiago#
cip_icon ="/home/qwertz/UCLA/uclales/Runs/00_ICON_GRID_CIP/"
monica_grid5 = "/home/qwertz/UCLA/uclales/Runs/Von_Monica_2024-07-22/grid_dz5/"

##########################################

grid5_00_tsds = xr.open_dataset(grid5_00+"rf01.ts.nc")#.sel(time=slice("2000-01-01T02:00:00.000000000", "2000-01-02T00:00:00.000000000"))
grid5_00_psds = xr.open_dataset(grid5_00+"rf01.ps.nc")#.sel(time=slice("2000-01-01T02:00:00.000000000", "2000-01-02T00:00:00.000000000"))
grid_icon_00_tsds = xr.open_dataset(grid_icon_00+"rf01.ts.nc")#.sel(time=slice("2000-01-01T02:00:00.000000000", "2000-01-02T00:00:00.000000000"))
grid_icon_00_psds = xr.open_dataset(grid_icon_00+"rf01.ps.nc")#.sel(time=slice("2000-01-01T02:00:00.000000000", "2000-01-02T00:00:00.000000000"))

cip_icon_tsds = xr.open_dataset(cip_icon+"rf01.ts.nc")#.sel(time=slice("2000-01-01T02:00:00.000000000", "2000-01-02T00:00:00.000000000"))
cip_icon_psds = xr.open_dataset(cip_icon+"rf01.ps.nc")#.sel(time=slice("2000-01-01T02:00:00.000000000", "2000-01-02T00:00:00.000000000"))
monica_grid5_tsds = xr.open_dataset(monica_grid5+"rf01.ts.nc")#.sel(time=slice("2000-01-01T02:00:00.000000000", "2000-01-02T00:00:00.000000000"))
monica_grid5_psds = xr.open_dataset(monica_grid5+"rf01.ps.nc")#.sel(time=slice("2000-01-01T02:00:00.000000000", "2000-01-02T00:00:00.000000000"))
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Vergleichsplot timexheight ICON

plt.figure(figsize=(15,8))
plt.title("Liquid water (Cloud) - CIP room")
plt.pcolormesh(cip_icon_psds["time"].values,cip_icon_psds["zt"].values,cip_icon_psds["l"].values.T, cmap="jet", vmax=0.5)
plt.ylim(400, 1100)
plt.colorbar()

plt.figure(figsize=(15,8))
plt.title("Liquid water (Cloud) - super computer Santiago")
plt.pcolormesh(grid_icon_00_psds["time"].values,grid_icon_00_psds["zt"].values,grid_icon_00_psds["l"].values.T, cmap="jet", vmax=0.5)
plt.ylim(400, 1100)
plt.colorbar()

# %%
# Vergleichsplot timexheight grid dz5

plt.figure(figsize=(15,8))
plt.title("Liquid water (Cloud) - PC in Santiago")
plt.pcolormesh(grid5_00_psds["time"].values,grid5_00_psds["zt"].values,grid5_00_psds["l"].values.T, cmap="jet", vmax=0.5)
plt.ylim(400, 1100)
plt.colorbar()

plt.figure(figsize=(7,8))
plt.title("Liquid water (Cloud) - crashed simulation on supercomputer Santiago")
plt.pcolormesh(monica_grid5_psds["time"].values, monica_grid5_psds["zt"].values,monica_grid5_psds["l"].values.T, cmap="jet", vmax=0.5)
plt.ylim(400, 1100)
plt.colorbar()

# %%
# Vergleichsplot LWP ICON:

# %%
# Vergleichsplot LWP grid dz5:

# %%
# Vergleichsplot Cloud top height ICON:

# %%
# Vergleichsplot Cloud top height grid dz5:
